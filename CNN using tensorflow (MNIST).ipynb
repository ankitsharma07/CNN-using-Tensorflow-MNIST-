# %% [markdown]
# # Building a CNN architecture using Tensorflow
#
# * Dataset - We are using [MNIST](http://yann.lecun.com/exdb/mnist/) dataset for our model.
# * It is a digit recognition task in which we identify digits (handwritten) from 0 to 9.
# * Each image is a 28x28 pixel square (784 pixels in total)

# %% [markdown]
# # CNN architecture
#
# * Convolution, Filter shape (5x5x6), Stride = 1, Padding = same
# * Max Pooling (2x2), Window shape (2x2), Stride = 2, Padding = same
# * ReLU
#
# * Convolution, Filter shape (5x5x16), Stride=1, Padding = same
# * Max Pooling (2x2), Window shape (2x2), Stride = 2, Padding = same
# * ReLU
#
# * Fully connected layers (128)
# * ReLU
# * Fully connected layers (10)
# * Softmax

# %% [markdown]
# ## 1. Importing Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import tensorflow as tf
import time

# %% [markdown]
# ## 2. Load data

# %%
from tensorflow.examples.tutorials.mnist import input_data

data = input_data.read_data_sets('data/MNIST/', one_hot=True)
# Out:
# Extracting data/MNIST/train-images-idx3-ubyte.gz
# Extracting data/MNIST/train-labels-idx1-ubyte.gz
# Extracting data/MNIST/t10k-images-idx3-ubyte.gz
# Extracting data/MNIST/t10k-labels-idx1-ubyte.gz

# %%
print('Size of: ')
print('- Training Set:\t\t{}'.format(len(data.train.labels)))
print('- Test Set:\t\t{}'.format(len(data.test.labels)))
print('- Validation Set:\t{}'.format(len(data.validation.labels)))
# Out:
# Size of:
# - Training Set:		55000
# - Test Set:		10000
# - Validation Set:	5000

# %% [markdown]
# ## 3. Placeholder variables

# %%
#Placeholder variable for the input imaage
x = tf.placeholder(tf.float32, shape=[None, 28*28], name = 'X')

#Reshape it into [num_images, image_height, image_width, num_channels]

x_image = tf.reshape(x, [-1, 28, 28, 1])

#Placeholder variables for the true labels associated with the images
y_true = tf.placeholder(tf.float32, shape =[None, 10], name = 'y_true')

y_true_cls = tf.argmax(y_true, dimension=1)
# Out:
# WARNING:tensorflow:From <ipython-input-7-865fa16ab6d0>:11: calling argmax (from tensorflow.python.ops.math_ops) with dimension is deprecated and will be removed in a future version.
# Instructions for updating:
# Use the `axis` argument instead

# %% [markdown]
# ## 4. Function for creating a new Convolutional Layer

# %%
def new_conv_layer(input, num_input_channels, filter_size, num_filters, name):
    with tf.variable_scope(name) as scope:
        #Shape of the filter weights for the convolution
        shape = [filter_size, filter_size, num_input_channels, num_filters]
        
        #Create new weights (filters) with the given shape
        weights = tf.Variable(tf.truncated_normal(shape, stddev=0.05))
        
        #Create new biases, one for each filter
        biases = tf.Variable(tf.constant(0.05, shape=[num_filters]))
        
        #Tensorflow operation for Convolution
        layer = tf.nn.conv2d(input = input, filter = weights, strides = [1,1,1,1], padding = 'SAME')
        
        #Add the biases to the result of the Convolution
        layer += biases
        
        return layer, weights

# %% [markdown]
# ## 5. Function for creating a new pooling layer

# %%
def new_pool_layer(input, name):
    with tf.variable_scope(name) as scope:
        
        #tensorflow operation for convolution
        layer = tf.nn.max_pool(value = input, ksize = [1, 2, 2, 1], strides = [1,2,2,1], padding='SAME')
        
        return layer

# %% [markdown]
# ## 6. Function for creating a new ReLU Layer

# %%
def new_relu_layer(input, name):
    with tf.variable_scope(name) as scope:
        
        #tensorflow operation for convolution
        layer = tf.nn.relu(input)
        
        return layer

# %% [markdown]
# ## 7. Function to create a fully connected layer

# %%
def new_fc_layer(input, num_inputs, num_outputs, name):
    
    with tf.variable_scope(name) as scope:
        
        #Create new weights and biases
        weights = tf.Variable(tf.truncated_normal([num_inputs, num_outputs], stddev = 0.05))
        
        biases = tf.Variable(tf.constant(0.05, shape = [num_outputs]))
        
        #Multiply the input layers and the weights and then add the bias values
        layer = tf.matmul(input, weights) + biases
        
        return layer

# %% [markdown]
# ## 8. Create the Convolutional Neural Network

# %%
#Convolution layer 1
layer_conv1, weights_conv1 = new_conv_layer(input = x_image, num_input_channels = 1, filter_size = 5, num_filters = 6, name = 'Conv1')

#Pooling layer 1
layer_pool1 = new_pool_layer(layer_conv1, name = 'pool1')

#ReLU layer 1
layer_relu1 = new_relu_layer(layer_pool1, name = 'relu1')

#Convolution layer 2
layer_conv2, weights_conv2 = new_conv_layer(input = layer_relu1, num_input_channels=6, filter_size = 5, num_filters=16, name = 'Conv2')

#Pooling layer 2
layer_pool2 = new_pool_layer(layer_conv2, name = 'pool2')

#ReLU layer 2
layer_relu2 = new_relu_layer(layer_pool2, name = 'relu2')

#Flatten layer
num_features = layer_relu2.get_shape()[1:4].num_elements()
layer_flat = tf.reshape(layer_relu2, [-1, num_features])

#Fully-connected layer 1
layer_fc1 = new_fc_layer(layer_flat, num_inputs=num_features, num_outputs=128, name = 'fc1')

#ReLU layer 3
layer_relu3 = new_relu_layer(layer_fc1, name = 'relu3')

#Fully-connected layer 2
layer_fc2 = new_fc_layer(input = layer_relu3, num_inputs=128, num_outputs=10, name='fc2')

# %%
#Use softmax function to normalize the output

with tf.variable_scope('Softmax'):
    y_pred = tf.nn.softmax(layer_fc2)
    y_pred_cls = tf.argmax(y_pred, dimension = 1)

# %% [markdown]
# ## 9. Cost Function

# %%
#Use cross entropy cost function
with tf.name_scope('cross_ent'):
    cross_entropy = tf.nn.softmax_cross_entropy_with_logits(logits = layer_fc2, labels = y_true)
    
    cost = tf.reduce_mean(cross_entropy)
# Out:
# WARNING:tensorflow:From <ipython-input-15-8ca58ec54b81>:3: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See tf.nn.softmax_cross_entropy_with_logits_v2.

# %% [markdown]
# ## 10. Optimizer

# %%
#Use adam optimizer
with tf.name_scope('optimizer'):
    optimizer = tf.train.AdamOptimizer(learning_rate = 1e-4).minimize(cost)

# %% [markdown]
# ## 11. Accuracy

# %%
with tf.name_scope('accuracy'):
    correct_prediction = tf.equal(y_pred_cls, y_true_cls)
    accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

# %%
# Initialize the file writer
writer = tf.summary.FileWriter('Training FileWriter/')
writer1 = tf.summary.FileWriter('Validation_FileWriter/')

# %%
#Add the cost and accuracy to the summary
tf.summary.scalar('loss', cost)
tf.summary.scalar('accuracy', accuracy)

#Merge all summaries together
merged_summary = tf.summary.merge_all()

# %%
num_epochs = 100
batch_size = 100

# %% [markdown]
# ## 12. TensorFlow Session

# %%
with tf.Session() as sess:
    #Initialize all variables
    sess.run(tf.global_variables_initializer())
    
    #Add the model graph to TensorBoard
    writer.add_graph(sess.graph)
    
    #Loop over number of epochs
    for epoch in range(num_epochs):
        start_time = time.time()
        train_accuracy = 0
        
        for batch in range(0, int(len(data.train.labels)/batch_size)):
            #Get a batch of images and labels
            x_batch, y_true_batch = data.train.next_batch(batch_size)
            
            #Put a batch into a dictionary with proper names for placeholder variables
            feed_dict_train = {x: x_batch, y_true: y_true_batch}
            
            #Run the optimizer using this batch of training set
            sess.run(optimizer, feed_dict = feed_dict_train)
            
            #Calculate the accuracy of the batch of the training data
            train_accuracy += sess.run(accuracy, feed_dict = feed_dict_train)
            
            #Generate summary with the current batch of data and write to the file
            summ = sess.run(mergerd_summary, feed_dict = feed_dict_train)
            
            writer.add_summary(summ, epoch*int(len(data.train.labels)/ batch_size) + batch)
            
        train_accuracy /= int(len(data.train.labels)/batch_size)
            
        #Generate summary and validate the model on entire validation set
        summ, vali_accuracy = sess.run([merged_summary, accuracy], feed_dict = {x: data.validation.images, y_true: data.validation.labels})
        writer1.add_summary(summ, epoch)
            
        end_time = time.time()
        
        print('Epoch '+str(epoch+1)+ 'completed: Time Usage: '+str(int(end_time-start_time))+' seconds')
        print('\tAccuracy:')
        print('\t- Training Accuracy:\t{}'.format(train_accuracy))
        print('\t- Validation Accuracy:\t{}'.format(vali_accuracy))
# Out:
# Epoch 1completed: Time Usage: 67 seconds
# 	Accuracy:
# 	- Training Accuracy:	0.7209636353362691
# 	- Validation Accuracy:	0.881600022315979
# Epoch 2completed: Time Usage: 62 seconds
# 	Accuracy:
# 	- Training Accuracy:	0.8962363645163449
# 	- Validation Accuracy:	0.9154000282287598
# Epoch 3completed: Time Usage: 62 seconds
# 	Accuracy:
# 	- Training Accuracy:	0.9187272746996447
# 	- Validation Accuracy:	0.9333999752998352
# Epoch 4completed: Time Usage: 60 seconds
# 	Accuracy:
# 	- Training Accuracy:	0.9326000023971904
# 	- Validation Accuracy:	0.9449999928474426
# Epoch 5completed: Time Usage: 65 seconds
# 	Accuracy:
# 	- Training Accuracy:	0.9438909107988531
# 	- Validation Accuracy:	0.9539999961853027
# Epoch 6completed: Time Usage: 74 seconds
# 	Accuracy:
# 	- Training Accuracy:	0.9527090926603837
# 	- Validation Accuracy:	0.9592000246047974
# Epoch 7completed: Time Usage: 66 seconds
# 	Accuracy:
# 	- Training Accuracy:	0.9605272775346583
# 	- Validation Accuracy:	0.965399980545044
# Epoch 8completed: Time Usage: 69 seconds
# 	Accuracy:
# 	- Training Accuracy:	0.9647272778641094
# 	- Validation Accuracy:	0.9678000211715698
# Epoch 9completed: Time Usage: 60 seconds
# 	Accuracy:
# 	- Training Accuracy:	0.9684000068361109
# 	- Validation Accuracy:	0.973800003528595
# Epoch 10completed: Time Usage: 60 seconds
# 	Accuracy:
# 	- Training Accuracy:	0.9712909179384058
# 	- Validation Accuracy:	0.973800003528595
# Epoch 11completed: Time Usage: 59 seconds
# 	Accuracy:
# 	- Training Accuracy:	0.9733090993491086
# 	- Validation Accuracy:	0.9765999913215637
# Epoch 12completed: Time Usage: 62 seconds
# 	Accuracy:
# 	- Training Accuracy:	0.9755818275971846
# 	- Validation Accuracy:	0.9768000245094299
# Epoch 13completed: Time Usage: 61 seconds
# 	Accuracy:
# 	- Training Accuracy:	0.9770181915976784
# 	- Validation Accuracy:	0.9779999852180481
# Epoch 14completed: Time Usage: 63 seconds
# 	Accuracy:
# 	- Training Accuracy:	0.979036375284195
# 	- Validation Accuracy:	0.9793999791145325
# Epoch 15completed: Time Usage: 61 seconds
# 	Accuracy:
# 	- Training Accuracy:	0.980254555940628
# 	- Validation Accuracy:	0.978600025177002
# Epoch 16completed: Time Usage: 62 seconds
# 	Accuracy:
# 	- Training Accuracy:	0.9807272836295041
# 	- Validation Accuracy:	0.9800000190734863
# Epoch 17completed: Time Usage: 60 seconds
# 	Accuracy:
# 	- Training Accuracy:	0.982345464663072
# 	- Validation Accuracy:	0.9814000129699707
# Epoch 18completed: Time Usage: 58 seconds
# 	Accuracy:
# 	- Training Accuracy:	0.9828181930021807
# 	- Validation Accuracy:	0.9815999865531921
# Epoch 19completed: Time Usage: 59 seconds
# 	Accuracy:
# 	- Training Accuracy:	0.9842545559189536
# 	- Validation Accuracy:	0.9819999933242798
# Epoch 20completed: Time Usage: 59 seconds
# 	Accuracy:
# 	- Training Accuracy:	0.9845272841236808
# 	- Validation Accuracy:	0.9837999939918518
# Epoch 21completed: Time Usage: 58 seconds
# 	Accuracy:
# 	- Training Accuracy:	0.9851272835514763
# 	- Validation Accuracy:	0.9843999743461609
# Epoch 22completed: Time Usage: 57 seconds
# 	Accuracy:
# 	- Training Accuracy:	0.9856000090729107
# 	- Validation Accuracy:	0.9843999743461609
# Epoch 23completed: Time Usage: 58 seconds
# 	Accuracy:
# 	- Training Accuracy:	0.9862181920355017
# 	- Validation Accuracy:	0.98580002784729
# Epoch 24completed: Time Usage: 58 seconds
# 	Accuracy:
# 	- Training Accuracy:	0.9863818287849426
# 	- Validation Accuracy:	0.9855999946594238
# Epoch 25completed: Time Usage: 58 seconds
# 	Accuracy:
# 	- Training Accuracy:	0.9871818276968869
# 	- Validation Accuracy:	0.98580002784729
# Epoch 26completed: Time Usage: 58 seconds
# 	Accuracy:
# 	- Training Accuracy:	0.9878909191218289
# 	- Validation Accuracy:	0.9860000014305115
# Epoch 27completed: Time Usage: 58 seconds
# 	Accuracy:
# 	- Training Accuracy:	0.9881818277185613
# 	- Validation Accuracy:	0.9850000143051147
# Epoch 28completed: Time Usage: 57 seconds
# 	Accuracy:
# 	- Training Accuracy:	0.9885454639521513
# 	- Validation Accuracy:	0.9860000014305115
# Epoch 29completed: Time Usage: 57 seconds
# 	Accuracy:
# 	- Training Accuracy:	0.9891272816874764
# 	- Validation Accuracy:	0.9876000285148621
# Epoch 30completed: Time Usage: 57 seconds
# 	Accuracy:
# 	- Training Accuracy:	0.9897636446085843
# 	- Validation Accuracy:	0.9846000075340271
# Epoch 31completed: Time Usage: 57 seconds
# 	Accuracy:
# 	- Training Accuracy:	0.9904545531489632
# 	- Validation Accuracy:	0.9861999750137329
# Epoch 32completed: Time Usage: 57 seconds
# 	Accuracy:
# 	- Training Accuracy:	0.9903090992840854
# 	- Validation Accuracy:	0.984000027179718
# Epoch 33completed: Time Usage: 57 seconds
# 	Accuracy:
# 	- Training Accuracy:	0.9907454623959281
# 	- Validation Accuracy:	0.9861999750137329
# Epoch 34completed: Time Usage: 57 seconds
# 	Accuracy:
# 	- Training Accuracy:	0.9910909170454199
# 	- Validation Accuracy:	0.9876000285148621
# Epoch 35completed: Time Usage: 57 seconds
# 	Accuracy:
# 	- Training Accuracy:	0.9914545530622656
# 	- Validation Accuracy:	0.9865999817848206
# Epoch 36completed: Time Usage: 57 seconds
# 	Accuracy:
# 	- Training Accuracy:	0.9915636441924355
# 	- Validation Accuracy:	0.9810000061988831
# Epoch 37completed: Time Usage: 58 seconds
# 	Accuracy:
# 	- Training Accuracy:	0.9919636435942216
# 	- Validation Accuracy:	0.9864000082015991
# Epoch 38completed: Time Usage: 58 seconds
# 	Accuracy:
# 	- Training Accuracy:	0.9924727336926894
# 	- Validation Accuracy:	0.9861999750137329
# Epoch 39completed: Time Usage: 57 seconds
# 	Accuracy:
# 	- Training Accuracy:	0.9924363705244932
# 	- Validation Accuracy:	0.9854000210762024
# Epoch 40completed: Time Usage: 57 seconds
# 	Accuracy:
# 	- Training Accuracy:	0.9929818241162733
# 	- Validation Accuracy:	0.9865999817848206
# Epoch 41completed: Time Usage: 57 seconds
# 	Accuracy:
# 	- Training Accuracy:	0.9932000062682412
# 	- Validation Accuracy:	0.9864000082015991
# Epoch 42completed: Time Usage: 58 seconds
# 	Accuracy:
# 	- Training Accuracy:	0.9935272785750302
# 	- Validation Accuracy:	0.9876000285148621
# Epoch 43completed: Time Usage: 57 seconds
# 	Accuracy:
# 	- Training Accuracy:	0.993836369189349
# 	- Validation Accuracy:	0.9869999885559082
# Epoch 44completed: Time Usage: 57 seconds
# 	Accuracy:
# 	- Training Accuracy:	0.9936545513976704
# 	- Validation Accuracy:	0.9869999885559082
# Epoch 45completed: Time Usage: 58 seconds
# 	Accuracy:
# 	- Training Accuracy:	0.9938000055876646
# 	- Validation Accuracy:	0.9850000143051147
# Epoch 46completed: Time Usage: 58 seconds
# 	Accuracy:
# 	- Training Accuracy:	0.9940545509078286
# 	- Validation Accuracy:	0.9872000217437744
# Epoch 47completed: Time Usage: 58 seconds
# 	Accuracy:
# 	- Training Accuracy:	0.9948181866515766
# 	- Validation Accuracy:	0.9865999817848206
# Epoch 48completed: Time Usage: 57 seconds
# 	Accuracy:
# 	- Training Accuracy:	0.9953090952743183
# 	- Validation Accuracy:	0.9883999824523926
# Epoch 49completed: Time Usage: 58 seconds
# 	Accuracy:
# 	- Training Accuracy:	0.9948363683440469
# 	- Validation Accuracy:	0.9882000088691711
# Epoch 50completed: Time Usage: 57 seconds
# 	Accuracy:
# 	- Training Accuracy:	0.9954545497894287
# 	- Validation Accuracy:	0.9869999885559082
# Epoch 51completed: Time Usage: 58 seconds
# 	Accuracy:
# 	- Training Accuracy:	0.9955818221785805
# 	- Validation Accuracy:	0.9851999878883362
# Epoch 52completed: Time Usage: 58 seconds
# 	Accuracy:
# 	- Training Accuracy:	0.9960727310180664
# 	- Validation Accuracy:	0.9855999946594238
# Epoch 53completed: Time Usage: 57 seconds
# 	Accuracy:
# 	- Training Accuracy:	0.9960909128189087
# 	- Validation Accuracy:	0.9868000149726868
# Epoch 54completed: Time Usage: 58 seconds
# 	Accuracy:
# 	- Training Accuracy:	0.9963454580307007
# 	- Validation Accuracy:	0.9868000149726868
# Epoch 55completed: Time Usage: 57 seconds
# 	Accuracy:
# 	- Training Accuracy:	0.9966000032424926
# 	- Validation Accuracy:	0.9879999756813049
# Epoch 56completed: Time Usage: 57 seconds
# 	Accuracy:
# 	- Training Accuracy:	0.9970181845534931
# 	- Validation Accuracy:	0.9851999878883362
# Epoch 57completed: Time Usage: 57 seconds
# 	Accuracy:
# 	- Training Accuracy:	0.9967272757400166
# 	- Validation Accuracy:	0.9855999946594238
# Epoch 58completed: Time Usage: 57 seconds
# 	Accuracy:
# 	- Training Accuracy:	0.9970545482635498
# 	- Validation Accuracy:	0.9872000217437744
# Epoch 59completed: Time Usage: 58 seconds
# 	Accuracy:
# 	- Training Accuracy:	0.9971818208694458
# 	- Validation Accuracy:	0.9886000156402588
# Epoch 60completed: Time Usage: 57 seconds
# 	Accuracy:
# 	- Training Accuracy:	0.9972909115661275
# 	- Validation Accuracy:	0.9883999824523926
# Epoch 61completed: Time Usage: 58 seconds
# 	Accuracy:
# 	- Training Accuracy:	0.9974909114837647
# 	- Validation Accuracy:	0.9876000285148621
# Epoch 62completed: Time Usage: 57 seconds
# 	Accuracy:
# 	- Training Accuracy:	0.9976181840896606
# 	- Validation Accuracy:	0.9864000082015991
# Epoch 63completed: Time Usage: 57 seconds
# 	Accuracy:
# 	- Training Accuracy:	0.9979272747039795
# 	- Validation Accuracy:	0.9836000204086304
# Epoch 64completed: Time Usage: 58 seconds
# 	Accuracy:
# 	- Training Accuracy:	0.9975090932846069
# 	- Validation Accuracy:	0.9855999946594238
# Epoch 65completed: Time Usage: 58 seconds
# 	Accuracy:
# 	- Training Accuracy:	0.9979272747039795
# 	- Validation Accuracy:	0.9878000020980835
# Epoch 66completed: Time Usage: 61 seconds
# 	Accuracy:
# 	- Training Accuracy:	0.9980545473098755
# 	- Validation Accuracy:	0.9876000285148621
# Epoch 67completed: Time Usage: 68 seconds
# 	Accuracy:
# 	- Training Accuracy:	0.9984181833267212
# 	- Validation Accuracy:	0.9882000088691711
# Epoch 68completed: Time Usage: 60 seconds
# 	Accuracy:
# 	- Training Accuracy:	0.9983090925216674
# 	- Validation Accuracy:	0.9864000082015991
# Epoch 69completed: Time Usage: 62 seconds
# 	Accuracy:
# 	- Training Accuracy:	0.9983272743225098
# 	- Validation Accuracy:	0.9878000020980835
# Epoch 70completed: Time Usage: 61 seconds
# 	Accuracy:
# 	- Training Accuracy:	0.9985272741317749
# 	- Validation Accuracy:	0.9873999953269958
# Epoch 71completed: Time Usage: 61 seconds
# 	Accuracy:
# 	- Training Accuracy:	0.9986727285385132
# 	- Validation Accuracy:	0.9873999953269958
# Epoch 72completed: Time Usage: 60 seconds
# 	Accuracy:
# 	- Training Accuracy:	0.9987636375427246
# 	- Validation Accuracy:	0.9868000149726868
# Epoch 73completed: Time Usage: 61 seconds
# 	Accuracy:
# 	- Training Accuracy:	0.9986909103393554
# 	- Validation Accuracy:	0.9886000156402588
# Epoch 74completed: Time Usage: 61 seconds
# 	Accuracy:
# 	- Training Accuracy:	0.9988727283477783
# 	- Validation Accuracy:	0.9861999750137329
# Epoch 75completed: Time Usage: 61 seconds
# 	Accuracy:
# 	- Training Accuracy:	0.9988545465469361
# 	- Validation Accuracy:	0.9872000217437744
# Epoch 76completed: Time Usage: 60 seconds
# 	Accuracy:
# 	- Training Accuracy:	0.998800001036037
# 	- Validation Accuracy:	0.9879999756813049
# Epoch 77completed: Time Usage: 61 seconds
# 	Accuracy:
# 	- Training Accuracy:	0.9989454555511474
# 	- Validation Accuracy:	0.9869999885559082
# Epoch 78completed: Time Usage: 61 seconds
# 	Accuracy:
# 	- Training Accuracy:	0.9990000009536744
# 	- Validation Accuracy:	0.9860000014305115
# Epoch 79completed: Time Usage: 70 seconds
# 	Accuracy:
# 	- Training Accuracy:	0.9990727281570435
# 	- Validation Accuracy:	0.9869999885559082
# Epoch 80completed: Time Usage: 66 seconds
# 	Accuracy:
# 	- Training Accuracy:	0.999109091758728
# 	- Validation Accuracy:	0.9894000291824341
# Epoch 81completed: Time Usage: 65 seconds
# 	Accuracy:
# 	- Training Accuracy:	0.9991636371612549
# 	- Validation Accuracy:	0.9873999953269958
# Epoch 82completed: Time Usage: 69 seconds
# 	Accuracy:
# 	- Training Accuracy:	0.9993272733688354
# 	- Validation Accuracy:	0.9850000143051147
# Epoch 83completed: Time Usage: 70 seconds
# 	Accuracy:
# 	- Training Accuracy:	0.9991636371612549
# 	- Validation Accuracy:	0.9864000082015991
# Epoch 84completed: Time Usage: 67 seconds
# 	Accuracy:
# 	- Training Accuracy:	0.999236364364624
# 	- Validation Accuracy:	0.9873999953269958
# Epoch 85completed: Time Usage: 66 seconds
# 	Accuracy:
# 	- Training Accuracy:	0.9992545461654663
# 	- Validation Accuracy:	0.9873999953269958
# Epoch 86completed: Time Usage: 64 seconds
# 	Accuracy:
# 	- Training Accuracy:	0.9994181823730469
# 	- Validation Accuracy:	0.9879999756813049
# Epoch 87completed: Time Usage: 63 seconds
# 	Accuracy:
# 	- Training Accuracy:	0.9995272731781006
# 	- Validation Accuracy:	0.9873999953269958
# Epoch 88completed: Time Usage: 61 seconds
# 	Accuracy:
# 	- Training Accuracy:	0.9995090913772583
# 	- Validation Accuracy:	0.9864000082015991
# Epoch 89completed: Time Usage: 59 seconds
# 	Accuracy:
# 	- Training Accuracy:	0.999618182182312
# 	- Validation Accuracy:	0.9890000224113464
# Epoch 90completed: Time Usage: 61 seconds
# 	Accuracy:
# 	- Training Accuracy:	0.9993818187713623
# 	- Validation Accuracy:	0.9828000068664551
# Epoch 91completed: Time Usage: 59 seconds
# 	Accuracy:
# 	- Training Accuracy:	0.9996727275848388
# 	- Validation Accuracy:	0.9872000217437744
# Epoch 92completed: Time Usage: 69 seconds
# 	Accuracy:
# 	- Training Accuracy:	0.9991636371612549
# 	- Validation Accuracy:	0.9869999885559082
# Epoch 93completed: Time Usage: 82 seconds
# 	Accuracy:
# 	- Training Accuracy:	0.9996000003814697
# 	- Validation Accuracy:	0.9868000149726868
# Epoch 94completed: Time Usage: 73 seconds
# 	Accuracy:
# 	- Training Accuracy:	0.9996545457839966
# 	- Validation Accuracy:	0.9878000020980835
# Epoch 95completed: Time Usage: 74 seconds
# 	Accuracy:
# 	- Training Accuracy:	0.9996727275848388
# 	- Validation Accuracy:	0.9887999892234802
# Epoch 96completed: Time Usage: 75 seconds
# 	Accuracy:
# 	- Training Accuracy:	0.9995818185806274
# 	- Validation Accuracy:	0.9873999953269958
# Epoch 97completed: Time Usage: 72 seconds
# 	Accuracy:
# 	- Training Accuracy:	0.9997818183898926
# 	- Validation Accuracy:	0.9860000014305115
# Epoch 98completed: Time Usage: 74 seconds
# 	Accuracy:
# 	- Training Accuracy:	0.9995454549789429
# 	- Validation Accuracy:	0.9864000082015991
# Epoch 99completed: Time Usage: 77 seconds
# 	Accuracy:
# 	- Training Accuracy:	0.9996727275848388
# 	- Validation Accuracy:	0.9873999953269958
# Epoch 100completed: Time Usage: 71 seconds
# 	Accuracy:
# 	- Training Accuracy:	0.9996545457839966
# 	- Validation Accuracy:	0.9883999824523926
